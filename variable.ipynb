# %% [markdown]
# variable is storage location for data to be stored
#
#
# # rules -
# variable name can have alphabets, numbers and underscore only
#
# - we cannot start a variable with numbers 1abc
# - we can use only underscore_ and no  other special characters like @,#,$
# - variable  name can start with an unaderscore - _abc
# - there should be no spaces between name o0f variable :
#    - my_name
#    - myname
#    - my name # is not correct

# %%
#operators
a=20
b=10
sub=a-b
product=a*b
div=a/b
print("subtraction",sub)
print("multiplication",product)
print("division",div)# gives quotient
# Out:
# subtraction 10
# multiplication 200
# division 2.0

# %%
#modulus/gives remainder
#division/gives quotient
num1=10
num2=4
print("Quotient",num1/num2)
print("Remainder",num1%num2)
# Out:
# Quotient 2.5
# Remainder 2

# %%
print("floor division",10//3)# IT GIVES ONLY INTEGER PART NOT DECIMAL PART
# Out:
# floor division 3

# %%
#EXPONENTIATION MAENS MULTIPLICATION WITH SAME NUMBER
#LIKE 10**3 MEANS 10*10*10

exponent=10**3
print(exponent)
# Out:
# 1000

# %%
print(5**6)
# Out:
# 15625

# %%
x=10
y=5
x+=5
y*=5
print(x)
print(y)
# Out:
# 15
# 25

# %%
b=10
b**=10
print(b)
# Out:
# 10000000000

# %%
c=20
c//=10
print(c)
# Out:
# 2

# %%
c=20
d=200
print(c==d)
print(c!=d)
print(c>d)
print(c<d)
# Out:
# False
# True
# False
# True

# %%
age=18
print(age>=18)
print(age<=18)
# Out:
# True
# True

# %%
age=19
country="India"
print(age>=18 and country=="India")
# Out:
# True

# %%
age=19
country="china"
print(age>=18 and country=="India")
# Out:
# False

# %%
#for visiting india 
country="china"
print(country=="india" or age>1)
# Out:
# True

# %%
a=10
print(not(a==10))
# Out:
# False

# %%
str="India"

# %%
str2=str#we check that the given 2 variables are equal or not
print(str2 is str)
# Out:
# True

# %%
str3="CHINA"
print(str is not str3)
# Out:
# True

# %%
str="my name is madhav"
print("madhav" in str)
print("happy" in str)
# Out:
# True
# False
