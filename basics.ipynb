# %% [markdown]
# `operators`
# - arithmetic
#     - addition
#         - subcategory1
#         - subcategory2
#     - subtraction
#     - multiplication
#     - division
#
# - logical
# - comparison
# - assignment

# %% [markdown]
# # OPERATOR
