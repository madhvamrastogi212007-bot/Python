# %%
a=10
b=-33333333388888
print(b)
print(a)
# Out:
# -33333333388888
# 10

# %%
#float
c=-836484774.88894634876
print(c,"this is floor type")
# Out:
# -836484774.8889463 this is floor type

# %%
name="Madhav"
print(name)
# Out:
# Madhav

# %%
institute="I STUDY AT DIGIPODIUM"
print(institute)
# Out:
# I STUDY AT DIGIPODIUM

# %%
a=2738
print(a==0)
print(a>0)
# Out:
# False
# True

# %% [markdown]
# - special datatypes

# %%
#list is mutable
fruits=["apple","banana","papaya","mango","strawberry"]
print(fruits)
# Out:
# ['apple', 'banana', 'papaya', 'mango', 'strawberry']

# %%
detail=["madhav",18,81.2]
print(detail)
# Out:
# ['madhav', 18, 81.2]

# %%
details=['madhav',18]
print(details)
# Out:
# ['madhav', 18]

# %%
#tuple is immutable
games=("Pubg","COD","valvorine","candy crush","subway surfer")
print(games)
# Out:
# ('Pubg', 'COD', 'valvorine', 'candy crush', 'subway surfer')

# %%
games=("Pubg","COD","valvorine","candy crush","subway surfer","Pubg")
print(games)
# Out:
# ('Pubg', 'COD', 'valvorine', 'candy crush', 'subway surfer', 'Pubg')

# %%
type(games)
# Out:
# tuple

# %%
#set is mutable and it is an unodered 
set={"Pubg","COD","valvorine","candy crush","subway surfer","Pubg","COD"}
print(set)
# Out:
# {'subway surfer', 'Pubg', 'candy crush', 'COD', 'valvorine'}

# %%
dict={ 
    "brand":"Ford",
    "model":"Mustang",
    "year":1967,
    "owner":"Shelby"

}

print(dict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1967, 'owner': 'Shelby'}

# %%
my_details={
    "name":"MADHAV",
    "institute":"DIGIPODIUM",
    "age":18,
    "marks":81.11111
}
print(my_details)
# Out:
# {'name': 'MADHAV', 'institute': 'DIGIPODIUM', 'age': 18, 'marks': 81.11111}

# %%
b="HELLO"
type(b)
# Out:
# str

# %%
a=2248493.39849
type(a)
# Out:
# float

# %%
multiple={5,10,15,20}
type(multiple)
# Out:
# set

# %%
multiple=[1,2,3,4,5]
type(multiple)
# Out:
# list

# %%
num={10,20,30,40,50,50,10,20,90,100,10}
print(num)
type(num)
# Out:
# {50, 100, 20, 90, 40, 10, 30}
# set

# %%
ab=[10,20,30,40,50,50,10,20,90,100,10]
print(ab)
type(ab)
# Out:
# [10, 20, 30, 40, 50, 50, 10, 20, 90, 100, 10]
# list

# %%
ab=(10,20,30,40,50,50,10,20,90,100,10)
print(ab)
type(ab)
# Out:
# (10, 20, 30, 40, 50, 50, 10, 20, 90, 100, 10)
# tuple
